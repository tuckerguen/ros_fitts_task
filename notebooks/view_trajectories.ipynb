# %%
import dill
import sys
sys.path.append("../src")
traj_path = "/home/tucker/thesis/ros_workspace/src/fitts_task/trials/tucker_0_0.001/2021-12-29_16-49-08-519180/trial.pkl"
with open(traj_path, 'rb') as f:
    trial = dill.load(f)

# %%
trial.plot()

# %%
trial.replay(speed=1)
