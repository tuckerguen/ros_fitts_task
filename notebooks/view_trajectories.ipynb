# %%
import dill
import sys
sys.path.append("../src")
traj_path = "/home/tucker/thesis/ros_workspace/src/fitts_task/trials/cathy_0.0_0.001/2021-12-30_13-59-38-218036/trial.pkl"
with open(traj_path, 'rb') as f:
    trial = dill.load(f)

# %%
trial.plot()

# %%
trial.replay(speed=1)
