# %%
import pickle
import numpy as np

# %%
traj_path = "../trials/tucker/2021-12-03_18-53-46-973105.pkl"
with open(traj_path, 'rb') as f:
    trial = pickle.load(f)
# Out:
# pygame 2.0.3 (SDL 2.0.16, Python 3.8.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
trial.plot()

# %%
trial.replay(speed=3)
