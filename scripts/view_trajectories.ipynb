# %%
import pickle
from fitts_task_node import Trajectory, Timepoint
# Out:
# pygame 2.0.3 (SDL 2.0.16, Python 3.8.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
traj_path = "../trajectories/test_traj.pkl"
with open(traj_path, 'rb') as f:
    trajs = pickle.load(f)

# %%
print(trajs)
for traj in trajs:
    traj.print()
    for tp in traj.data:
        tp.print()
# Out:
# [<fitts_task_node.Trajectory object at 0x7f38f852b1f0>, <fitts_task_node.Trajectory object at 0x7f38b446c8b0>, <fitts_task_node.Trajectory object at 0x7f38b4486ca0>, <fitts_task_node.Trajectory object at 0x7f38b44264f0>, <fitts_task_node.Trajectory object at 0x7f38b442ce80>, <fitts_task_node.Trajectory object at 0x7f38b4455d30>, <fitts_task_node.Trajectory object at 0x7f38b43e7af0>, <fitts_task_node.Trajectory object at 0x7f38b4403b50>, <fitts_task_node.Trajectory object at 0x7f38b4415070>, <fitts_task_node.Trajectory object at 0x7f38b441ed90>, <fitts_task_node.Trajectory object at 0x7f38b43b1670>, <fitts_task_node.Trajectory object at 0x7f38b43c40a0>, <fitts_task_node.Trajectory object at 0x7f38b43c9580>, <fitts_task_node.Trajectory object at 0x7f38b43dd460>, <fitts_task_node.Trajectory object at 0x7f38b436a580>, <fitts_task_node.Trajectory object at 0x7f38b4374d60>, <fitts_task_node.Trajectory object at 0x7f38b4386100>, <fitts_task_node.Trajectory object at 0x7f38b4394760>, <fitts_
# ...
